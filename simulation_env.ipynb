# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib import patches

from datasets import CubeObstacle, CylinderObstacle
from utils.config import Hyperparameters as hp
from utils.tools import calc_sig_strength

np.random.seed(42)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.cm as cm

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(-100, 100)
ax.set_ylim(-100, 100)

# 컬러맵에서 색상을 가져오기
colors = cm.get_cmap("tab20", 16)  # 10가지 색상 제공

obstacle_ls = {
    "cube1": patches.Rectangle((-30, 25), 60, 20, facecolor=colors(0)),
    "cube2": patches.Rectangle((-30, -25), 10, 35, facecolor=colors(1)),
    "cube3": patches.Rectangle((-30, -60), 60, 20, facecolor=colors(2)),
    # "cube4": patches.Rectangle((-70, -20), 20, 65, facecolor=colors(3)),
    "cube5": patches.Rectangle((50, -20), 20, 25, facecolor=colors(4)),
    # "cylinder1": patches.Circle((-60, -50), 20, facecolor=colors(5)),
    # "cylinder3": patches.Circle((60, -50), 10, facecolor=colors(6)),
    "cylinder4": patches.Circle((10, -5), 15, facecolor=colors(7)),
}

# 도형 추가
for obstacle in obstacle_ls.values():
    ax.add_patch(obstacle)

plt.show()
# Out:
# /var/folders/gm/x9jlk7p54xjc9qmd5h06cgd40000gn/T/ipykernel_4406/431014563.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", 16)  # 10가지 색상 제공

# %%
obstacle_ls = {
    "cube1": CubeObstacle(-30, 25, 35, 60, 20, 0.3),
    "cube2": CubeObstacle(-30, -25, 45, 10, 35, 0.3),
    "cube3": CubeObstacle(-30, -60, 35, 60, 20, 0.3),
    # "cube4": CubeObstacle(-70, -20, 20, 20, 65, 0.3),
    "cube5": CubeObstacle(50, -20, 35, 25, 25, 0.3),
    "cylinder1": CylinderObstacle(10, -5,  70, 15, 0.3),
    # "cylinder2": CylinderObstacle(-60, -50, 40, 20, 0.3),
    # "cylinder3": CylinderObstacle(60, -50, 30, 10, 0.3),
}

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# ax.view_init(elev=90, azim=270)

for obstacle in obstacle_ls.values():
    obstacle.plot(ax)

ax.set_xlim(-hp.area_size//2, hp.area_size//2)
ax.set_ylim(-hp.area_size//2, hp.area_size//2)
ax.set_zlim(0, 70)
plt.show()
